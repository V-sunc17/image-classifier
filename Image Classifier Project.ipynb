# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import torch
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
from torch import nn

import helper
from torch import optim
import torch.nn.functional as F

from workspace_utils import active_session

import fc_model

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# Define your transforms for the training, validation, and testing sets


data_transforms = transforms.Compose([transforms.Resize(255),
                                 transforms.CenterCrop(224),
                                 transforms.ToTensor(),transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))]                                )


#  Load the datasets with ImageFolder
image_datasets_train = datasets.ImageFolder(train_dir, transform=data_transforms)
image_datasets_test = datasets.ImageFolder(test_dir, transform=data_transforms)
image_datasets_val = datasets.ImageFolder(valid_dir, transform=data_transforms)

#  Using the image datasets and the trainforms, define the dataloaders
dataloaders_train = torch.utils.data.DataLoader(image_datasets_train ,batch_size=64, shuffle=True)
dataloaders_test = torch.utils.data.DataLoader(image_datasets_test,batch_size=8)
dataloaders_val = torch.utils.data.DataLoader(image_datasets_val,batch_size=8)

images, labels = next(iter(dataloaders_train))
#helper.imshow(images[0], normalize=False)
#print(labels[0])
#print(images[0])
images[0].size()
print(images[0])
print(labels[0])
# Out:
# tensor([[[-0.4911, -0.4911, -0.4397,  ..., -1.9295, -1.9467, -2.0152],
#          [-0.6109, -0.5767, -0.5253,  ..., -1.9295, -1.9467, -1.9980],
#          [-0.6452, -0.6281, -0.5938,  ..., -1.9809, -1.9980, -2.0152],
#          ...,
#          [ 0.2282,  0.1426,  0.0398,  ..., -1.5699, -1.6213, -1.6384],
#          [ 0.2282,  0.1426,  0.0398,  ..., -1.6042, -1.6555, -1.6727],
#          [ 0.2453,  0.1426,  0.0398,  ..., -1.5870, -1.6555, -1.7069]],
#
#         [[ 0.2227,  0.2227,  0.2577,  ..., -1.6155, -1.6506, -1.7206],
#          [ 0.1527,  0.1702,  0.2052,  ..., -1.6506, -1.6681, -1.7206],
#          [ 0.1352,  0.1352,  0.1352,  ..., -1.7031, -1.7206, -1.7381],
#          ...,
#          [ 0.6954,  0.6254,  0.5728,  ..., -1.1253, -1.1779, -1.1954],
#          [ 0.6954,  0.6254,  0.5378,  ..., -1.1604, -1.2129, -1.2304],
#          [ 0.6954,  0.6078,  0.5203,  ..., -1.1429, -1.2129, -1.2654]],
#
#         [[ 0.0256,  0.0605,  0.1302,  ..., -1.6824, -1.7173, -1.7696],
#          [-0.1312, -0.0615,  0.0256,  ..., -1.6999, -1.7173, -1.7696],
#          [-0.2184, -0.1487, -0.0964,  ..., -1.7522, -1.7696, -1.7870],
#          ...,
#          [ 1.0888,  1.0017,  0.8971,  ..., -1.3687, -1.4210, -1.4384],
#          [ 1.0888,  0.9668,  0.8797,  ..., -1.4036, -1.4559, -1.4733],
#          [ 1.0888,  0.9494,  0.8448,  ..., -1.3861, -1.4559, -1.5081]]])
# tensor(1)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)
    print(cat_to_name)
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# Build and train your network
# Import pretrained model
model = models.densenet121(pretrained=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.

# %%
# Check the key
print(model._modules.keys())
# Out:
# odict_keys(['features', 'classifier'])

# %%
# Freeze parameters so we don't backprop through them
for param in model.parameters():
    param.requires_grad = False

from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(1024, 500)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(500, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
model.classifier = classifier

#                          ('output', nn.LogSoftmax(dim=1))

# %%
criterion = nn.NLLLoss()
# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.SGD(model.classifier.parameters(), lr=0.001)
optimizer.zero_grad()
device = 'cuda'
model.to(device)
# run with awake function
with active_session():
    epochs = 10
    for epoch in range(epochs):
        for ii, (inputs, labels) in enumerate(dataloaders_train):

            # Move input and label tensors to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
 #           optimizer.zero_grad()
            outputs = model.forward(inputs)
            loss = criterion(outputs, labels)
            print(loss)
            loss.backward()
            optimizer.step()
#            print(ii)
# Out:
# tensor(1.00000e-03 *
#        2.0040, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5984, device='cuda:0')
# tensor(0.1565, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8853, device='cuda:0')
# tensor(1.00000e-02 *
#        7.4877, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9603, device='cuda:0')
# tensor(1.00000e-02 *
#        2.6751, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5799, device='cuda:0')
# tensor(1.00000e-03 *
#        8.9072, device='cuda:0')
# tensor(1.00000e-02 *
#        3.2520, device='cuda:0')
# tensor(1.00000e-02 *
#        2.6577, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2905, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7351, device='cuda:0')
# tensor(1.00000e-03 *
#        4.8386, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0413, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0925, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5335, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7115, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3103, device='cuda:0')
# tensor(1.00000e-03 *
#        1.8608, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5610, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3462, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3177, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3987, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7799, device='cuda:0')
# tensor(1.00000e-03 *
#        9.0407, device='cuda:0')
# tensor(1.00000e-02 *
#        9.9454, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9850, device='cuda:0')
# tensor(1.00000e-02 *
#        4.8676, device='cuda:0')
# tensor(1.00000e-03 *
#        5.6948, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0046, device='cuda:0')
# tensor(1.00000e-03 *
#        8.4038, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5954, device='cuda:0')
# tensor(1.00000e-02 *
#        8.3913, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0283, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2129, device='cuda:0')
# tensor(1.00000e-04 *
#        5.5239, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5964, device='cuda:0')
# tensor(1.00000e-03 *
#        8.5640, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3495, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8787, device='cuda:0')
# tensor(1.00000e-03 *
#        5.0895, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1684, device='cuda:0')
# tensor(1.00000e-03 *
#        4.9243, device='cuda:0')
# tensor(1.00000e-03 *
#        7.8394, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2053, device='cuda:0')
# tensor(1.00000e-04 *
#        4.1434, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0499, device='cuda:0')
# tensor(1.00000e-03 *
#        3.6487, device='cuda:0')
# tensor(1.00000e-02 *
#        3.2548, device='cuda:0')
# tensor(1.00000e-03 *
#        6.7360, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7835, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4632, device='cuda:0')
# tensor(1.00000e-04 *
#        5.1278, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8745, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5466, device='cuda:0')
# tensor(1.00000e-03 *
#        6.9632, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5941, device='cuda:0')
# tensor(1.00000e-02 *
#        4.8825, device='cuda:0')
# tensor(1.00000e-03 *
#        6.1356, device='cuda:0')
# tensor(1.00000e-03 *
#        4.3640, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5278, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5317, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0604, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4592, device='cuda:0')
# tensor(1.00000e-03 *
#        1.7569, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3079, device='cuda:0')
# tensor(1.00000e-03 *
#        3.1234, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3856, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6904, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4855, device='cuda:0')
# tensor(1.00000e-04 *
#        3.5080, device='cuda:0')
# tensor(1.00000e-04 *
#        6.4823, device='cuda:0')
# tensor(1.00000e-03 *
#        3.7878, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4005, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0645, device='cuda:0')
# tensor(1.00000e-04 *
#        5.0846, device='cuda:0')
# tensor(1.00000e-04 *
#        2.1616, device='cuda:0')
# tensor(1.00000e-03 *
#        5.9932, device='cuda:0')
# tensor(1.00000e-02 *
#        8.6640, device='cuda:0')
# tensor(1.00000e-04 *
#        4.8181, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3598, device='cuda:0')
# tensor(1.00000e-04 *
#        8.3017, device='cuda:0')
# tensor(1.00000e-05 *
#        9.4950, device='cuda:0')
# tensor(1.00000e-03 *
#        3.6268, device='cuda:0')
# tensor(1.00000e-04 *
#        8.1098, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4589, device='cuda:0')
# tensor(1.00000e-04 *
#        7.9185, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2366, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6775, device='cuda:0')
# tensor(1.00000e-04 *
#        4.8879, device='cuda:0')
# tensor(1.00000e-02 *
#        3.5889, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0257, device='cuda:0')
# tensor(1.00000e-02 *
#        3.3316, device='cuda:0')
# tensor(1.00000e-04 *
#        6.6161, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4533, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0748, device='cuda:0')
# tensor(1.00000e-04 *
#        6.1765, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3349, device='cuda:0')
# tensor(1.00000e-03 *
#        3.1229, device='cuda:0')
# tensor(1.00000e-03 *
#        9.3927, device='cuda:0')
# tensor(1.00000e-04 *
#        2.5454, device='cuda:0')
# tensor(1.00000e-04 *
#        1.4329, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4520, device='cuda:0')
# tensor(1.00000e-04 *
#        3.4457, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6704, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5517, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7366, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6231, device='cuda:0')
# tensor(1.00000e-03 *
#        7.0039, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3613, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1276, device='cuda:0')
# tensor(1.00000e-03 *
#        2.2763, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0144, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6517, device='cuda:0')
# tensor(1.00000e-03 *
#        1.8899, device='cuda:0')
# tensor(1.00000e-04 *
#        4.7579, device='cuda:0')
# tensor(1.00000e-03 *
#        4.5716, device='cuda:0')
# tensor(1.00000e-05 *
#        8.4281, device='cuda:0')
# tensor(1.00000e-05 *
#        3.2961, device='cuda:0')
# tensor(0.1101, device='cuda:0')
# tensor(1.00000e-03 *
#        6.6272, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9480, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6345, device='cuda:0')
# tensor(1.00000e-04 *
#        4.6313, device='cuda:0')
# tensor(1.00000e-03 *
#        3.2454, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3900, device='cuda:0')
# tensor(1.00000e-05 *
#        9.2298, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3853, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2038, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4926, device='cuda:0')
# tensor(1.00000e-03 *
#        5.5289, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2231, device='cuda:0')
# tensor(1.00000e-04 *
#        2.8622, device='cuda:0')
# tensor(1.00000e-03 *
#        9.3198, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3489, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1019, device='cuda:0')
# tensor(0.1397, device='cuda:0')
# tensor(1.00000e-05 *
#        4.2498, device='cuda:0')
# tensor(1.00000e-04 *
#        4.6876, device='cuda:0')
# tensor(1.00000e-03 *
#        5.9793, device='cuda:0')
# tensor(1.00000e-03 *
#        6.8527, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1516, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0779, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8217, device='cuda:0')
# tensor(1.00000e-03 *
#        8.3755, device='cuda:0')
# tensor(0.1352, device='cuda:0')
# tensor(0.1506, device='cuda:0')
# tensor(0.1206, device='cuda:0')
# tensor(1.00000e-04 *
#        4.2513, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0771, device='cuda:0')
# tensor(0.1223, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0396, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8207, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6182, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5170, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9596, device='cuda:0')
# tensor(1.00000e-04 *
#        1.0404, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6265, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0183, device='cuda:0')
# tensor(1.00000e-03 *
#        4.2860, device='cuda:0')
# tensor(1.00000e-02 *
#        5.7136, device='cuda:0')
# tensor(0.1086, device='cuda:0')
# tensor(1.00000e-04 *
#        1.1793, device='cuda:0')
# tensor(1.00000e-04 *
#        9.0259, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9833, device='cuda:0')
# tensor(1.00000e-03 *
#        3.6818, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3530, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1933, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1547, device='cuda:0')
# tensor(1.00000e-04 *
#        5.3534, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0223, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1153, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1117, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2344, device='cuda:0')
# tensor(1.00000e-03 *
#        1.7582, device='cuda:0')
# tensor(1.00000e-03 *
#        4.1603, device='cuda:0')
# tensor(1.00000e-03 *
#        8.1946, device='cuda:0')
# tensor(1.00000e-04 *
#        1.8322, device='cuda:0')
# tensor(1.00000e-02 *
#        5.6371, device='cuda:0')
# tensor(1.00000e-03 *
#        5.5710, device='cuda:0')
# tensor(1.00000e-04 *
#        8.4734, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1020, device='cuda:0')
# tensor(1.00000e-04 *
#        5.5966, device='cuda:0')
# tensor(1.00000e-03 *
#        4.0588, device='cuda:0')
# tensor(1.00000e-04 *
#        2.9272, device='cuda:0')
# tensor(1.00000e-04 *
#        2.9811, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3309, device='cuda:0')
# tensor(1.00000e-04 *
#        9.1508, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8761, device='cuda:0')
# tensor(1.00000e-03 *
#        9.1771, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5464, device='cuda:0')
# tensor(1.00000e-03 *
#        2.0637, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3294, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6934, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5576, device='cuda:0')
# tensor(1.00000e-03 *
#        3.3589, device='cuda:0')
# tensor(1.00000e-04 *
#        6.3020, device='cuda:0')
# tensor(1.00000e-03 *
#        1.8436, device='cuda:0')
# tensor(1.00000e-02 *
#        6.3805, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7298, device='cuda:0')
# tensor(1.00000e-03 *
#        4.6340, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6448, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5624, device='cuda:0')
# tensor(1.00000e-04 *
#        2.0182, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7375, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0014, device='cuda:0')
# tensor(1.00000e-02 *
#        8.1692, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9441, device='cuda:0')
# tensor(1.00000e-02 *
#        1.9085, device='cuda:0')
# tensor(1.00000e-03 *
#        6.0531, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9979, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1189, device='cuda:0')
# tensor(1.00000e-04 *
#        9.0364, device='cuda:0')
# tensor(1.00000e-03 *
#        3.1268, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0196, device='cuda:0')
# tensor(1.00000e-02 *
#        6.3823, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4859, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1877, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0377, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8169, device='cuda:0')
# tensor(1.00000e-03 *
#        2.5394, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7747, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7506, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0938, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3774, device='cuda:0')
# tensor(1.00000e-04 *
#        5.8118, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9852, device='cuda:0')
# tensor(1.00000e-03 *
#        1.8836, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2787, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6203, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2613, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3301, device='cuda:0')
# tensor(0.1364, device='cuda:0')
# tensor(1.00000e-04 *
#        2.7126, device='cuda:0')
# tensor(1.00000e-02 *
#        4.8173, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6065, device='cuda:0')
# tensor(1.00000e-03 *
#        9.8254, device='cuda:0')
# tensor(1.00000e-03 *
#        4.6185, device='cuda:0')
# tensor(1.00000e-02 *
#        7.7396, device='cuda:0')
# tensor(1.00000e-04 *
#        1.2514, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5384, device='cuda:0')
# tensor(1.00000e-03 *
#        8.5128, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2292, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0982, device='cuda:0')
# tensor(1.00000e-04 *
#        5.5528, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2819, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7382, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5462, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0800, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5743, device='cuda:0')
# tensor(1.00000e-03 *
#        2.4951, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6573, device='cuda:0')
# tensor(1.00000e-02 *
#        6.2553, device='cuda:0')
# tensor(0.1730, device='cuda:0')
# tensor(1.00000e-03 *
#        7.5944, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7736, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8714, device='cuda:0')
# tensor(1.00000e-03 *
#        3.2183, device='cuda:0')
# tensor(1.00000e-02 *
#        9.7365, device='cuda:0')
# tensor(1.00000e-03 *
#        7.0117, device='cuda:0')
# tensor(1.00000e-03 *
#        2.5809, device='cuda:0')
# tensor(1.00000e-04 *
#        3.6988, device='cuda:0')
# tensor(1.00000e-03 *
#        5.2989, device='cuda:0')
# tensor(1.00000e-04 *
#        1.8895, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8922, device='cuda:0')
# tensor(1.00000e-03 *
#        4.1893, device='cuda:0')
# tensor(1.00000e-04 *
#        9.4062, device='cuda:0')
# tensor(1.00000e-03 *
#        3.4018, device='cuda:0')
# tensor(1.00000e-02 *
#        6.7284, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2654, device='cuda:0')
# tensor(1.00000e-02 *
#        3.7463, device='cuda:0')
# tensor(1.00000e-02 *
#        5.6793, device='cuda:0')
# tensor(1.00000e-03 *
#        3.4496, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8907, device='cuda:0')
# tensor(1.00000e-03 *
#        2.2267, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2842, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2442, device='cuda:0')
# tensor(1.00000e-02 *
#        4.8477, device='cuda:0')
# tensor(1.00000e-03 *
#        7.6781, device='cuda:0')
# tensor(1.00000e-03 *
#        4.1137, device='cuda:0')
# tensor(1.00000e-03 *
#        7.9067, device='cuda:0')
# tensor(1.00000e-02 *
#        8.1785, device='cuda:0')
# tensor(1.00000e-03 *
#        7.4683, device='cuda:0')
# tensor(1.00000e-04 *
#        7.1681, device='cuda:0')
# tensor(1.00000e-03 *
#        4.5061, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1110, device='cuda:0')
# tensor(1.00000e-02 *
#        5.6366, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2098, device='cuda:0')
# tensor(1.00000e-04 *
#        5.4786, device='cuda:0')
# tensor(1.00000e-05 *
#        9.8020, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0427, device='cuda:0')
# tensor(1.00000e-03 *
#        5.3575, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1284, device='cuda:0')
# tensor(1.00000e-04 *
#        5.3269, device='cuda:0')
# tensor(1.00000e-04 *
#        6.3422, device='cuda:0')
# tensor(1.00000e-02 *
#        5.9905, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1932, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8836, device='cuda:0')
# tensor(1.00000e-04 *
#        5.0768, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1921, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3104, device='cuda:0')
# tensor(1.00000e-03 *
#        4.5218, device='cuda:0')
# tensor(1.00000e-02 *
#        8.1171, device='cuda:0')
# tensor(1.00000e-03 *
#        3.3778, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3238, device='cuda:0')
# tensor(1.00000e-02 *
#        3.5207, device='cuda:0')
# tensor(1.00000e-02 *
#        6.5564, device='cuda:0')
# tensor(1.00000e-05 *
#        2.2968, device='cuda:0')
# tensor(1.00000e-03 *
#        4.9813, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3812, device='cuda:0')
# tensor(1.00000e-03 *
#        4.1002, device='cuda:0')
# tensor(1.00000e-04 *
#        4.8918, device='cuda:0')
# tensor(1.00000e-03 *
#        6.8704, device='cuda:0')
# tensor(1.00000e-04 *
#        9.9093, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5909, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5429, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5717, device='cuda:0')
# tensor(1.00000e-03 *
#        1.7003, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9272, device='cuda:0')
# tensor(1.00000e-04 *
#        9.3210, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3869, device='cuda:0')
# tensor(1.00000e-04 *
#        1.9830, device='cuda:0')
# tensor(1.00000e-04 *
#        2.7299, device='cuda:0')
# tensor(1.00000e-05 *
#        9.7096, device='cuda:0')
# tensor(1.00000e-04 *
#        8.8745, device='cuda:0')
# tensor(1.00000e-04 *
#        3.4657, device='cuda:0')
# tensor(1.00000e-04 *
#        5.8222, device='cuda:0')
# tensor(0.1559, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3373, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5599, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2321, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5321, device='cuda:0')
# tensor(1.00000e-05 *
#        3.0488, device='cuda:0')
# tensor(1.00000e-03 *
#        5.6931, device='cuda:0')
# tensor(1.00000e-03 *
#        2.2803, device='cuda:0')
# tensor(1.00000e-03 *
#        8.6570, device='cuda:0')
# tensor(1.00000e-02 *
#        4.7558, device='cuda:0')
# tensor(1.00000e-03 *
#        5.4330, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4788, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8993, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5443, device='cuda:0')
# tensor(1.00000e-03 *
#        8.5723, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5272, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2461, device='cuda:0')
# tensor(1.00000e-02 *
#        4.8398, device='cuda:0')
# tensor(0.1500, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3503, device='cuda:0')
# tensor(1.00000e-04 *
#        5.9670, device='cuda:0')
# tensor(0.2132, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4271, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5325, device='cuda:0')
# tensor(1.00000e-03 *
#        1.7344, device='cuda:0')
# tensor(1.00000e-04 *
#        9.7102, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6350, device='cuda:0')
# tensor(1.00000e-03 *
#        3.7271, device='cuda:0')
# tensor(1.00000e-03 *
#        4.0255, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1561, device='cuda:0')
# tensor(1.00000e-04 *
#        6.2254, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0450, device='cuda:0')
# tensor(1.00000e-03 *
#        9.6207, device='cuda:0')
# tensor(1.00000e-02 *
#        3.8275, device='cuda:0')
# tensor(1.00000e-02 *
#        9.7442, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5434, device='cuda:0')
# tensor(1.00000e-02 *
#        8.6514, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9430, device='cuda:0')
# tensor(1.00000e-03 *
#        5.4952, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2287, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0377, device='cuda:0')
# tensor(1.00000e-04 *
#        3.6973, device='cuda:0')
# tensor(1.00000e-04 *
#        5.3734, device='cuda:0')
# tensor(1.00000e-03 *
#        3.2127, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9944, device='cuda:0')
# tensor(1.00000e-02 *
#        5.5163, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4769, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7155, device='cuda:0')
# tensor(1.00000e-04 *
#        6.2048, device='cuda:0')
# tensor(0.1169, device='cuda:0')
# tensor(1.00000e-04 *
#        7.0307, device='cuda:0')
# tensor(1.00000e-03 *
#        3.7339, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0345, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8872, device='cuda:0')
# tensor(1.00000e-04 *
#        8.2207, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7773, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6992, device='cuda:0')
# tensor(1.00000e-03 *
#        3.3565, device='cuda:0')
# tensor(1.00000e-04 *
#        4.5776, device='cuda:0')
# tensor(1.00000e-04 *
#        2.0269, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7407, device='cuda:0')
# tensor(1.00000e-04 *
#        1.1471, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1900, device='cuda:0')
# tensor(1.00000e-02 *
#        7.0425, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5805, device='cuda:0')
# tensor(1.00000e-02 *
#        5.9646, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1050, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6953, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0720, device='cuda:0')
# tensor(1.00000e-04 *
#        7.6103, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5248, device='cuda:0')
# tensor(1.00000e-04 *
#        6.6403, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6371, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5886, device='cuda:0')
# tensor(1.00000e-03 *
#        5.5102, device='cuda:0')
# tensor(1.00000e-04 *
#        1.2550, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5231, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5844, device='cuda:0')
# tensor(1.00000e-03 *
#        4.8071, device='cuda:0')
# tensor(1.00000e-02 *
#        5.1841, device='cuda:0')
# tensor(1.00000e-03 *
#        9.9499, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5095, device='cuda:0')
# tensor(1.00000e-02 *
#        1.9510, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9787, device='cuda:0')
# tensor(1.00000e-03 *
#        7.5980, device='cuda:0')
# tensor(0.1002, device='cuda:0')
# tensor(1.00000e-02 *
#        6.4088, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3493, device='cuda:0')
# tensor(1.00000e-04 *
#        8.0687, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0471, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2688, device='cuda:0')
# tensor(1.00000e-02 *
#        5.0034, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2373, device='cuda:0')
# tensor(1.00000e-02 *
#        5.1183, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4374, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5832, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0378, device='cuda:0')
# tensor(1.00000e-02 *
#        9.8874, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6622, device='cuda:0')
# tensor(1.00000e-04 *
#        1.7804, device='cuda:0')
# tensor(1.00000e-03 *
#        1.4261, device='cuda:0')
# tensor(1.00000e-04 *
#        9.9069, device='cuda:0')
# tensor(1.00000e-03 *
#        3.7286, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8723, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9259, device='cuda:0')
# tensor(1.00000e-02 *
#        7.6954, device='cuda:0')
# tensor(1.00000e-02 *
#        1.9613, device='cuda:0')
# tensor(1.00000e-03 *
#        4.9543, device='cuda:0')
# tensor(1.00000e-03 *
#        5.8126, device='cuda:0')
# tensor(1.00000e-03 *
#        1.3165, device='cuda:0')
# tensor(1.00000e-04 *
#        6.1291, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7051, device='cuda:0')
# tensor(1.00000e-04 *
#        5.3272, device='cuda:0')
# tensor(1.00000e-02 *
#        7.7725, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0941, device='cuda:0')
# tensor(0.1268, device='cuda:0')
# tensor(1.00000e-03 *
#        9.5104, device='cuda:0')
# tensor(1.00000e-03 *
#        9.9515, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3949, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3370, device='cuda:0')
# tensor(0.1197, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1071, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6370, device='cuda:0')
# tensor(1.00000e-04 *
#        2.8542, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7825, device='cuda:0')
# tensor(0.1078, device='cuda:0')
# tensor(1.00000e-04 *
#        7.5784, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4964, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6295, device='cuda:0')
# tensor(1.00000e-04 *
#        8.7193, device='cuda:0')
# tensor(1.00000e-02 *
#        7.9056, device='cuda:0')
# tensor(1.00000e-03 *
#        7.4221, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2802, device='cuda:0')
# tensor(1.00000e-04 *
#        3.0303, device='cuda:0')
# tensor(1.00000e-03 *
#        4.2498, device='cuda:0')
# tensor(1.00000e-03 *
#        4.9808, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5641, device='cuda:0')
# tensor(1.00000e-02 *
#        6.4353, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4489, device='cuda:0')
# tensor(1.00000e-02 *
#        3.8299, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3864, device='cuda:0')
# tensor(1.00000e-04 *
#        2.9325, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4613, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8410, device='cuda:0')
# tensor(1.00000e-04 *
#        4.2188, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6747, device='cuda:0')
# tensor(1.00000e-03 *
#        5.1461, device='cuda:0')
# tensor(0.2669, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0769, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4319, device='cuda:0')
# tensor(1.00000e-03 *
#        9.8869, device='cuda:0')
# tensor(1.00000e-02 *
#        3.5616, device='cuda:0')
# tensor(1.00000e-03 *
#        7.6694, device='cuda:0')
# tensor(1.00000e-04 *
#        6.7627, device='cuda:0')
# tensor(1.00000e-03 *
#        6.7804, device='cuda:0')
# tensor(1.00000e-02 *
#        6.2379, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1861, device='cuda:0')
# tensor(1.00000e-03 *
#        7.3212, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1777, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7182, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6121, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2224, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3981, device='cuda:0')
# tensor(1.00000e-02 *
#        6.0008, device='cuda:0')
# tensor(1.00000e-04 *
#        2.8577, device='cuda:0')
# tensor(1.00000e-02 *
#        4.1419, device='cuda:0')
# tensor(1.00000e-02 *
#        1.6917, device='cuda:0')
# tensor(1.00000e-04 *
#        4.4835, device='cuda:0')
# tensor(1.00000e-02 *
#        4.7845, device='cuda:0')
# tensor(1.00000e-03 *
#        8.6172, device='cuda:0')
# tensor(1.00000e-03 *
#        3.7827, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0908, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4781, device='cuda:0')
# tensor(1.00000e-02 *
#        9.6932, device='cuda:0')
# tensor(1.00000e-02 *
#        4.1951, device='cuda:0')
# tensor(1.00000e-04 *
#        8.3485, device='cuda:0')
# tensor(1.00000e-04 *
#        9.6840, device='cuda:0')
# tensor(1.00000e-02 *
#        3.2401, device='cuda:0')
# tensor(1.00000e-04 *
#        2.3130, device='cuda:0')
# tensor(1.00000e-03 *
#        5.4795, device='cuda:0')
# tensor(1.00000e-04 *
#        8.1834, device='cuda:0')
# tensor(1.00000e-03 *
#        3.8148, device='cuda:0')
# tensor(0.1915, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3205, device='cuda:0')
# tensor(1.00000e-04 *
#        9.6047, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3511, device='cuda:0')
# tensor(0.4011, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2890, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3974, device='cuda:0')
# tensor(1.00000e-02 *
#        4.6178, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9114, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7267, device='cuda:0')
# tensor(1.00000e-02 *
#        4.6343, device='cuda:0')
# tensor(1.00000e-04 *
#        6.6155, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2941, device='cuda:0')
# tensor(1.00000e-02 *
#        2.1775, device='cuda:0')
# tensor(1.00000e-02 *
#        9.0037, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1326, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7500, device='cuda:0')
# tensor(1.00000e-04 *
#        6.5863, device='cuda:0')
# tensor(1.00000e-04 *
#        2.5031, device='cuda:0')
# tensor(1.00000e-03 *
#        2.4662, device='cuda:0')
# tensor(1.00000e-02 *
#        9.3231, device='cuda:0')
# tensor(1.00000e-02 *
#        5.8771, device='cuda:0')
# tensor(1.00000e-03 *
#        2.0474, device='cuda:0')
# tensor(0.2573, device='cuda:0')
# tensor(1.00000e-02 *
#        5.3838, device='cuda:0')
# tensor(1.00000e-03 *
#        6.3955, device='cuda:0')
# tensor(1.00000e-03 *
#        2.3877, device='cuda:0')
# tensor(1.00000e-02 *
#        7.3737, device='cuda:0')
# tensor(1.00000e-04 *
#        3.4434, device='cuda:0')
# tensor(1.00000e-03 *
#        2.5567, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0757, device='cuda:0')
# tensor(0.1644, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2794, device='cuda:0')
# tensor(1.00000e-02 *
#        6.7747, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0042, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4785, device='cuda:0')
# tensor(1.00000e-03 *
#        7.2353, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4035, device='cuda:0')
# tensor(1.00000e-03 *
#        5.9757, device='cuda:0')
# tensor(1.00000e-02 *
#        4.6254, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6858, device='cuda:0')
# tensor(1.00000e-02 *
#        5.7345, device='cuda:0')
# tensor(1.00000e-03 *
#        7.7381, device='cuda:0')
# tensor(0.1015, device='cuda:0')
# tensor(1.00000e-03 *
#        6.6431, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7448, device='cuda:0')
# tensor(1.00000e-02 *
#        8.2455, device='cuda:0')
# tensor(1.00000e-03 *
#        8.5458, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0367, device='cuda:0')
# tensor(1.00000e-03 *
#        1.4487, device='cuda:0')
# tensor(1.00000e-02 *
#        8.3231, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0152, device='cuda:0')
# tensor(1.00000e-03 *
#        2.5724, device='cuda:0')
# tensor(1.00000e-02 *
#        5.8900, device='cuda:0')
# tensor(0.1077, device='cuda:0')
# tensor(1.00000e-03 *
#        7.3722, device='cuda:0')
# tensor(1.00000e-02 *
#        2.1542, device='cuda:0')
# tensor(1.00000e-04 *
#        6.2302, device='cuda:0')
# tensor(1.00000e-02 *
#        3.8661, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5724, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5710, device='cuda:0')
# tensor(0.1412, device='cuda:0')
# tensor(1.00000e-04 *
#        5.3895, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1080, device='cuda:0')
# tensor(0.1341, device='cuda:0')
# tensor(1.00000e-03 *
#        7.0423, device='cuda:0')
# tensor(1.00000e-03 *
#        4.4952, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5287, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7811, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3167, device='cuda:0')
# tensor(0.1376, device='cuda:0')
# tensor(1.00000e-04 *
#        5.6303, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7526, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0140, device='cuda:0')
# tensor(1.00000e-02 *
#        5.1714, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0825, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1096, device='cuda:0')
# tensor(1.00000e-03 *
#        6.4570, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0127, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0788, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2176, device='cuda:0')
# tensor(1.00000e-03 *
#        5.1671, device='cuda:0')
# tensor(1.00000e-03 *
#        4.3579, device='cuda:0')
# tensor(1.00000e-03 *
#        6.2822, device='cuda:0')
# tensor(1.00000e-04 *
#        6.2588, device='cuda:0')
# tensor(1.00000e-03 *
#        9.5767, device='cuda:0')
# tensor(1.00000e-02 *
#        4.9572, device='cuda:0')
# tensor(1.00000e-03 *
#        4.5361, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5874, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4350, device='cuda:0')
# tensor(0.1577, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4965, device='cuda:0')
# tensor(1.00000e-02 *
#        9.0512, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0816, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1578, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4068, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0412, device='cuda:0')
# tensor(1.00000e-03 *
#        3.8592, device='cuda:0')
# tensor(1.00000e-03 *
#        7.8534, device='cuda:0')
# tensor(1.00000e-03 *
#        3.9535, device='cuda:0')
# tensor(1.00000e-02 *
#        8.5426, device='cuda:0')
# tensor(1.00000e-02 *
#        9.9274, device='cuda:0')
# tensor(1.00000e-02 *
#        8.4954, device='cuda:0')
# tensor(0.1223, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8083, device='cuda:0')
# tensor(0.1003, device='cuda:0')
# tensor(1.00000e-04 *
#        2.5222, device='cuda:0')
# tensor(0.7090, device='cuda:0')
# tensor(1.00000e-04 *
#        3.5557, device='cuda:0')
# tensor(1.00000e-03 *
#        6.1482, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7094, device='cuda:0')
# tensor(1.00000e-04 *
#        6.1786, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0536, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0807, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3077, device='cuda:0')
# tensor(1.00000e-04 *
#        9.1052, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0115, device='cuda:0')
# tensor(1.00000e-02 *
#        9.6620, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6216, device='cuda:0')
# tensor(1.00000e-02 *
#        6.6176, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5224, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0613, device='cuda:0')
# tensor(1.00000e-03 *
#        3.0020, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4970, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1574, device='cuda:0')
# tensor(0.1291, device='cuda:0')
# tensor(1.00000e-03 *
#        4.6478, device='cuda:0')
# tensor(1.00000e-02 *
#        6.7142, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3639, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0266, device='cuda:0')
# tensor(1.00000e-02 *
#        1.9037, device='cuda:0')
# tensor(1.00000e-02 *
#        8.2478, device='cuda:0')
# tensor(0.2230, device='cuda:0')
# tensor(1.00000e-02 *
#        3.6859, device='cuda:0')
# tensor(1.00000e-02 *
#        2.1617, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0743, device='cuda:0')
# tensor(1.00000e-02 *
#        2.1943, device='cuda:0')
# tensor(0.1565, device='cuda:0')
# tensor(1.00000e-02 *
#        9.3121, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2497, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2430, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9074, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9351, device='cuda:0')
# tensor(1.00000e-03 *
#        9.3004, device='cuda:0')
# tensor(1.00000e-03 *
#        8.3699, device='cuda:0')
# tensor(0.1205, device='cuda:0')
# tensor(1.00000e-02 *
#        5.3366, device='cuda:0')
# tensor(0.1988, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5254, device='cuda:0')
# tensor(1.00000e-04 *
#        2.5055, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5346, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8241, device='cuda:0')
# tensor(1.00000e-02 *
#        6.4413, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2596, device='cuda:0')
# tensor(1.00000e-03 *
#        1.8686, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4269, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2195, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0267, device='cuda:0')
# tensor(0.1007, device='cuda:0')
# tensor(1.00000e-04 *
#        8.6656, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7002, device='cuda:0')
# tensor(0.1381, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6048, device='cuda:0')
# tensor(1.00000e-02 *
#        6.1247, device='cuda:0')
# tensor(1.00000e-02 *
#        8.4002, device='cuda:0')
# tensor(1.00000e-04 *
#        3.4195, device='cuda:0')
# tensor(1.00000e-02 *
#        6.2824, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3702, device='cuda:0')
# tensor(1.00000e-03 *
#        5.1433, device='cuda:0')
# tensor(1.00000e-03 *
#        6.8256, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9463, device='cuda:0')
# tensor(1.00000e-02 *
#        3.7584, device='cuda:0')
# tensor(1.00000e-02 *
#        6.0479, device='cuda:0')
# tensor(1.00000e-02 *
#        6.0960, device='cuda:0')
# tensor(1.00000e-04 *
#        2.2769, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3086, device='cuda:0')
# tensor(1.00000e-03 *
#        2.1364, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8358, device='cuda:0')
# tensor(1.00000e-02 *
#        5.7854, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0321, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5209, device='cuda:0')
# tensor(1.00000e-03 *
#        8.5795, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2456, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8202, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5606, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0786, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2496, device='cuda:0')
# tensor(1.00000e-02 *
#        6.5055, device='cuda:0')
# tensor(0.1931, device='cuda:0')
# tensor(0.2447, device='cuda:0')
# tensor(1.00000e-04 *
#        6.0394, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2194, device='cuda:0')
# tensor(1.00000e-02 *
#        5.5289, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5363, device='cuda:0')
# tensor(1.00000e-03 *
#        8.0164, device='cuda:0')
# tensor(0.1802, device='cuda:0')
# tensor(1.00000e-03 *
#        3.3291, device='cuda:0')
# tensor(0.3768, device='cuda:0')
# tensor(1.00000e-03 *
#        2.9395, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8732, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9301, device='cuda:0')
# tensor(1.00000e-03 *
#        4.3996, device='cuda:0')
# tensor(1.00000e-02 *
#        9.7664, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5914, device='cuda:0')
# tensor(0.2372, device='cuda:0')
# tensor(0.2140, device='cuda:0')
# tensor(1.00000e-03 *
#        9.9455, device='cuda:0')
# tensor(0.3768, device='cuda:0')
# tensor(1.00000e-02 *
#        9.3147, device='cuda:0')
# tensor(1.00000e-03 *
#        9.8947, device='cuda:0')
# tensor(0.2613, device='cuda:0')
# tensor(1.00000e-03 *
#        3.8760, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4292, device='cuda:0')
# tensor(1.00000e-03 *
#        5.7522, device='cuda:0')
# tensor(1.00000e-02 *
#        8.5360, device='cuda:0')
# tensor(1.00000e-04 *
#        1.1402, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2785, device='cuda:0')
# tensor(1.00000e-04 *
#        1.9059, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1573, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4458, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3604, device='cuda:0')
# tensor(1.00000e-02 *
#        7.2182, device='cuda:0')
# tensor(1.00000e-05 *
#        4.4376, device='cuda:0')
# tensor(1.00000e-03 *
#        5.2564, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5066, device='cuda:0')
# tensor(0.2556, device='cuda:0')
# tensor(1.00000e-03 *
#        9.9044, device='cuda:0')
# tensor(1.00000e-03 *
#        2.7606, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7268, device='cuda:0')
# tensor(1.00000e-02 *
#        8.6302, device='cuda:0')
# tensor(1.00000e-02 *
#        1.7230, device='cuda:0')
# tensor(1.00000e-04 *
#        9.1052, device='cuda:0')
# tensor(1.00000e-02 *
#        7.4012, device='cuda:0')
# tensor(1.00000e-02 *
#        6.0588, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6708, device='cuda:0')
# tensor(1.00000e-02 *
#        6.3054, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5622, device='cuda:0')
# tensor(1.00000e-03 *
#        5.9753, device='cuda:0')
# tensor(0.1322, device='cuda:0')
# tensor(1.00000e-03 *
#        2.0564, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5664, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7808, device='cuda:0')
# tensor(1.00000e-03 *
#        7.9835, device='cuda:0')
# tensor(1.00000e-03 *
#        3.2378, device='cuda:0')
# tensor(0.1798, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1275, device='cuda:0')
# tensor(1.00000e-04 *
#        9.1746, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4052, device='cuda:0')
# tensor(1.00000e-02 *
#        9.9922, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1209, device='cuda:0')
# tensor(1.00000e-02 *
#        3.3145, device='cuda:0')
# tensor(1.00000e-02 *
#        3.3915, device='cuda:0')
# tensor(1.00000e-04 *
#        4.4775, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9830, device='cuda:0')
# tensor(1.00000e-03 *
#        8.2026, device='cuda:0')
# tensor(1.00000e-02 *
#        6.2885, device='cuda:0')
# tensor(1.00000e-03 *
#        7.0278, device='cuda:0')
# tensor(1.00000e-02 *
#        5.8864, device='cuda:0')
# tensor(1.00000e-03 *
#        3.4925, device='cuda:0')
# tensor(1.00000e-03 *
#        7.8299, device='cuda:0')
# tensor(1.00000e-03 *
#        4.5677, device='cuda:0')
# tensor(1.00000e-02 *
#        6.1213, device='cuda:0')
# tensor(1.00000e-02 *
#        5.0852, device='cuda:0')
# tensor(1.00000e-03 *
#        3.6229, device='cuda:0')
# tensor(1.00000e-02 *
#        1.3393, device='cuda:0')
# tensor(1.00000e-03 *
#        8.9988, device='cuda:0')
# tensor(1.00000e-03 *
#        9.0587, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2885, device='cuda:0')
# tensor(0.1050, device='cuda:0')
# tensor(1.00000e-03 *
#        3.9603, device='cuda:0')
# tensor(1.00000e-04 *
#        8.9407, device='cuda:0')
# tensor(1.00000e-02 *
#        3.8241, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2984, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8711, device='cuda:0')
# tensor(1.00000e-04 *
#        8.6409, device='cuda:0')
# tensor(1.00000e-02 *
#        8.5868, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4066, device='cuda:0')
# tensor(1.00000e-03 *
#        8.2176, device='cuda:0')
# tensor(1.00000e-02 *
#        8.0695, device='cuda:0')
# tensor(1.00000e-02 *
#        5.9083, device='cuda:0')
# tensor(1.00000e-03 *
#        3.4546, device='cuda:0')
# tensor(1.00000e-02 *
#        5.4096, device='cuda:0')
# tensor(1.00000e-03 *
#        3.3529, device='cuda:0')
# tensor(1.00000e-03 *
#        8.8877, device='cuda:0')
# tensor(1.00000e-02 *
#        6.6467, device='cuda:0')
# tensor(1.00000e-02 *
#        3.6548, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9797, device='cuda:0')
# tensor(1.00000e-02 *
#        8.0312, device='cuda:0')
# tensor(1.00000e-03 *
#        8.7289, device='cuda:0')
# tensor(0.1262, device='cuda:0')
# tensor(1.00000e-04 *
#        4.3085, device='cuda:0')
# tensor(1.00000e-02 *
#        9.8282, device='cuda:0')
# tensor(1.00000e-03 *
#        1.1778, device='cuda:0')
# tensor(0.2089, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0468, device='cuda:0')
# tensor(0.1136, device='cuda:0')
# tensor(1.00000e-02 *
#        2.3723, device='cuda:0')
# tensor(1.00000e-03 *
#        6.1483, device='cuda:0')
# tensor(1.00000e-02 *
#        9.5682, device='cuda:0')
# tensor(0.2623, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2271, device='cuda:0')
# tensor(1.00000e-03 *
#        1.2427, device='cuda:0')
# tensor(1.00000e-02 *
#        1.8216, device='cuda:0')
# tensor(1.00000e-03 *
#        3.1535, device='cuda:0')
# tensor(0.1191, device='cuda:0')
# tensor(1.00000e-02 *
#        9.1514, device='cuda:0')
# tensor(1.00000e-02 *
#        4.1574, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2675, device='cuda:0')
# tensor(1.00000e-02 *
#        6.3095, device='cuda:0')
# tensor(1.00000e-03 *
#        7.6669, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7770, device='cuda:0')
# tensor(1.00000e-03 *
#        1.9605, device='cuda:0')
# tensor(1.00000e-04 *
#        6.5231, device='cuda:0')
# tensor(1.00000e-02 *
#        3.5632, device='cuda:0')
# tensor(1.00000e-02 *
#        2.1792, device='cuda:0')
# tensor(1.00000e-04 *
#        2.3478, device='cuda:0')
# tensor(1.00000e-03 *
#        8.6152, device='cuda:0')
# tensor(1.00000e-02 *
#        2.4702, device='cuda:0')
# tensor(1.00000e-02 *
#        5.8385, device='cuda:0')
# tensor(0.1056, device='cuda:0')
# tensor(1.00000e-03 *
#        8.8858, device='cuda:0')
# tensor(1.00000e-03 *
#        4.3674, device='cuda:0')
# tensor(1.00000e-03 *
#        6.5467, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0815, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0868, device='cuda:0')
# tensor(1.00000e-04 *
#        2.3791, device='cuda:0')
# tensor(1.00000e-03 *
#        3.8219, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1413, device='cuda:0')
# tensor(1.00000e-03 *
#        7.8960, device='cuda:0')
# tensor(1.00000e-02 *
#        4.9607, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8571, device='cuda:0')
# tensor(1.00000e-02 *
#        6.4838, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2940, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8502, device='cuda:0')
# tensor(1.00000e-03 *
#        6.3327, device='cuda:0')
# tensor(1.00000e-03 *
#        2.2027, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6311, device='cuda:0')
# tensor(0.1340, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9362, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0006, device='cuda:0')
# tensor(1.00000e-02 *
#        4.6799, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4699, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9826, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0905, device='cuda:0')
# tensor(1.00000e-04 *
#        5.6171, device='cuda:0')
# tensor(1.00000e-03 *
#        2.6018, device='cuda:0')
# tensor(1.00000e-02 *
#        5.4882, device='cuda:0')
# tensor(0.1072, device='cuda:0')
# tensor(1.00000e-03 *
#        5.5802, device='cuda:0')
# tensor(1.00000e-03 *
#        2.5934, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8953, device='cuda:0')
# tensor(1.00000e-03 *
#        9.1014, device='cuda:0')
# tensor(1.00000e-02 *
#        6.1423, device='cuda:0')
# tensor(0.1238, device='cuda:0')
# tensor(1.00000e-04 *
#        5.4616, device='cuda:0')
# tensor(1.00000e-02 *
#        8.0444, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5515, device='cuda:0')
# tensor(1.00000e-02 *
#        3.6691, device='cuda:0')
# tensor(1.00000e-02 *
#        5.6826, device='cuda:0')
# tensor(0.1092, device='cuda:0')
# tensor(1.00000e-02 *
#        3.7698, device='cuda:0')
# tensor(0.1714, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0229, device='cuda:0')
# tensor(1.00000e-03 *
#        6.0410, device='cuda:0')
# tensor(0.1187, device='cuda:0')
# tensor(0.1175, device='cuda:0')
# tensor(1.00000e-02 *
#        7.0152, device='cuda:0')
# tensor(1.00000e-03 *
#        3.5229, device='cuda:0')
# tensor(0.1143, device='cuda:0')
# tensor(1.00000e-02 *
#        4.2436, device='cuda:0')
# tensor(0.1810, device='cuda:0')
# tensor(1.00000e-03 *
#        4.3797, device='cuda:0')
# tensor(1.00000e-02 *
#        7.3214, device='cuda:0')
# tensor(1.00000e-02 *
#        9.7038, device='cuda:0')
# tensor(1.00000e-02 *
#        4.1757, device='cuda:0')
# tensor(0.1270, device='cuda:0')
# tensor(1.00000e-02 *
#        4.9340, device='cuda:0')
# tensor(1.00000e-03 *
#        1.5714, device='cuda:0')
# tensor(1.00000e-02 *
#        8.9271, device='cuda:0')
# tensor(0.2775, device='cuda:0')
# tensor(0.1057, device='cuda:0')
# tensor(1.00000e-02 *
#        8.1213, device='cuda:0')
# tensor(1.00000e-02 *
#        8.9697, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0437, device='cuda:0')
# tensor(0.1850, device='cuda:0')
# tensor(1.00000e-02 *
#        3.1151, device='cuda:0')
# tensor(0.2507, device='cuda:0')
# tensor(0.1020, device='cuda:0')
# tensor(1.00000e-02 *
#        4.0471, device='cuda:0')
# tensor(1.00000e-03 *
#        4.7025, device='cuda:0')
# tensor(0.4864, device='cuda:0')
# tensor(0.1696, device='cuda:0')
# tensor(1.00000e-03 *
#        9.9715, device='cuda:0')
# tensor(0.2148, device='cuda:0')
# tensor(1.00000e-02 *
#        9.0958, device='cuda:0')
# tensor(1.00000e-02 *
#        5.1940, device='cuda:0')
# tensor(0.4837, device='cuda:0')
# tensor(1.00000e-02 *
#        4.9036, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5533, device='cuda:0')
# tensor(0.1958, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0054, device='cuda:0')
# tensor(0.1384, device='cuda:0')
# tensor(0.1007, device='cuda:0')
# tensor(0.1089, device='cuda:0')
# tensor(1.00000e-02 *
#        6.3531, device='cuda:0')
# tensor(0.1209, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0010, device='cuda:0')
# tensor(1.00000e-03 *
#        2.8237, device='cuda:0')
# tensor(1.00000e-02 *
#        2.9209, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5107, device='cuda:0')
# tensor(1.00000e-02 *
#        1.4391, device='cuda:0')
# tensor(0.2309, device='cuda:0')
# tensor(1.00000e-02 *
#        5.2488, device='cuda:0')
# tensor(1.00000e-02 *
#        5.8366, device='cuda:0')
# tensor(1.00000e-02 *
#        3.6731, device='cuda:0')
# tensor(0.1008, device='cuda:0')
# tensor(0.1276, device='cuda:0')
# tensor(1.00000e-02 *
#        5.1677, device='cuda:0')
# tensor(1.00000e-03 *
#        3.1131, device='cuda:0')
# tensor(0.1126, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9252, device='cuda:0')
# tensor(0.1051, device='cuda:0')
# tensor(1.00000e-02 *
#        4.5320, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4762, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2810, device='cuda:0')
# tensor(1.00000e-02 *
#        2.8394, device='cuda:0')
# tensor(1.00000e-02 *
#        1.9077, device='cuda:0')
# tensor(1.00000e-02 *
#        6.1013, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0636, device='cuda:0')
# tensor(0.1718, device='cuda:0')
# tensor(1.00000e-02 *
#        3.3520, device='cuda:0')
# tensor(0.1118, device='cuda:0')
# tensor(1.00000e-02 *
#        8.9813, device='cuda:0')
# tensor(1.00000e-02 *
#        6.9594, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4052, device='cuda:0')
# tensor(1.00000e-02 *
#        1.1089, device='cuda:0')
# tensor(1.00000e-02 *
#        5.6707, device='cuda:0')
# tensor(0.1099, device='cuda:0')
# tensor(1.00000e-03 *
#        1.4498, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9536, device='cuda:0')
# tensor(0.1821, device='cuda:0')
# tensor(0.1042, device='cuda:0')
# tensor(0.1147, device='cuda:0')
# tensor(0.1126, device='cuda:0')
# tensor(1.00000e-02 *
#        7.0396, device='cuda:0')
# tensor(0.1246, device='cuda:0')
# tensor(0.1888, device='cuda:0')
# tensor(0.2284, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9068, device='cuda:0')
# tensor(0.1250, device='cuda:0')
# tensor(0.2692, device='cuda:0')
# tensor(1.00000e-02 *
#        5.0090, device='cuda:0')
# tensor(1.00000e-02 *
#        6.6836, device='cuda:0')
# tensor(1.00000e-02 *
#        3.0394, device='cuda:0')
# tensor(1.00000e-02 *
#        1.0122, device='cuda:0')
# tensor(0.1357, device='cuda:0')
# tensor(0.2093, device='cuda:0')
# tensor(1.00000e-02 *
#        2.2576, device='cuda:0')
# tensor(0.3181, device='cuda:0')
# tensor(0.2363, device='cuda:0')
# tensor(0.1819, device='cuda:0')
# tensor(0.2037, device='cuda:0')
# tensor(1.00000e-02 *
#        5.3517, device='cuda:0')
# tensor(0.2320, device='cuda:0')
# tensor(0.1473, device='cuda:0')
# tensor(1.00000e-02 *
#        6.2633, device='cuda:0')
# tensor(0.1103, device='cuda:0')
# tensor(0.2382, device='cuda:0')
# tensor(1.00000e-02 *
#        1.2924, device='cuda:0')
# tensor(1.00000e-02 *
#        5.4074, device='cuda:0')
# tensor(0.3150, device='cuda:0')
# tensor(1.00000e-02 *
#        2.7507, device='cuda:0')
# tensor(0.1706, device='cuda:0')
# tensor(1.00000e-02 *
#        4.3439, device='cuda:0')
# tensor(0.1553, device='cuda:0')
# tensor(0.2388, device='cuda:0')
# tensor(1.00000e-02 *
#        2.5604, device='cuda:0')
# tensor(1.00000e-02 *
#        3.8163, device='cuda:0')
# tensor(0.1558, device='cuda:0')
# tensor(1.00000e-02 *
#        9.6103, device='cuda:0')
# tensor(1.00000e-03 *
#        8.0322, device='cuda:0')
# tensor(1.00000e-02 *
#        8.8961, device='cuda:0')
# tensor(0.1195, device='cuda:0')
# tensor(1.00000e-02 *
#        8.1873, device='cuda:0')
# tensor(0.1009, device='cuda:0')
# tensor(1.00000e-02 *
#        2.0607, device='cuda:0')
# tensor(1.00000e-02 *
#        8.4394, device='cuda:0')
# tensor(1.00000e-03 *
#        1.6084, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5563, device='cuda:0')
# tensor(1.00000e-03 *
#        2.0201, device='cuda:0')
# tensor(1.00000e-02 *
#        6.5879, device='cuda:0')
# tensor(1.00000e-02 *
#        3.4951, device='cuda:0')
# tensor(1.00000e-02 *
#        3.9860, device='cuda:0')
# tensor(0.2023, device='cuda:0')
# tensor(0.2426, device='cuda:0')
# tensor(1.00000e-02 *
#        4.4504, device='cuda:0')
# tensor(1.00000e-03 *
#        5.8985, device='cuda:0')
# tensor(0.1644, device='cuda:0')
# tensor(1.00000e-03 *
#        1.0490, device='cuda:0')
# tensor(1.00000e-02 *
#        1.5860, device='cuda:0')

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Implement a function for the validation pass
test_loss = 0
accuracy = 0
criterion = nn.NLLLoss()
for images, labels in dataloaders_val:

#        images.resize_(images.shape[0], 784)
    device = 'cuda'
    model.to(device)
    images, labels = images.to(device), labels.to(device)
    output = model.forward(images)
    test_loss += criterion(output, labels).item()

    ps = torch.exp(output)
    equality = (labels.data == ps.max(dim=1)[1])
    accuracy += equality.type(torch.FloatTensor).mean()

# %%
print("Test Loss: {:.3f}.. ".format(test_loss/len(dataloaders_val)),
      "Test Accuracy: {:.3f}".format(accuracy/len(dataloaders_val)))
# Out:
# Test Loss: 12.075..  Test Accuracy: 0.131

# %%
# check test dataset
 
test_loss = 0
accuracy = 0

for images, labels in dataloaders_test:

#        images.resize_(images.shape[0], 784)
    device = 'cuda'
    model.to(device)
    images, labels = images.to(device), labels.to(device)
    output = model.forward(images)
    test_loss += criterion(output, labels).item()

    ps = torch.exp(output)
    equality = (labels.data == ps.max(dim=1)[1])
    accuracy += equality.type(torch.FloatTensor).mean()

# %%
print("Test Loss: {:.3f}.. ".format(test_loss/len(dataloaders_val)),
      "Test Accuracy: {:.3f}".format(accuracy/len(dataloaders_val)))

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# Save the checkpoint  
checkpoint = {'input_size': 1024,
              'output_size': 102,
              'state_dict': model.state_dict()}

torch.save(checkpoint, 'fufu1.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Write a function that loads a checkpoint and rebuilds the model
def load_fufu(filepath):

    checkpoint = torch.load(filepath)
#    model = fc_model.Network(checkpoint['input_size'],
#                             checkpoint['output_size'])
    model.load_state_dict(checkpoint['state_dict'])
    
    return model

# %%
# Load existing saved model from fufu.pth
model = models.densenet121(pretrained=True)
from collections import OrderedDict
classifier = nn.Sequential(OrderedDict([
                          ('fc1', nn.Linear(1024, 500)),
                          ('relu', nn.ReLU()),
                          ('fc2', nn.Linear(500, 102)),
                          ('output', nn.LogSoftmax(dim=1))
                          ]))
model.classifier = classifier

#                          ('output', nn.LogSoftmax(dim=1))
model = load_fufu('fufu.pth')
print(model)
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=1024, out_features=500, bias=True)
#     (relu): ReLU()
#     (fc2): Linear(in_features=500, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np

# %%
def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''    
    # Process a PIL image for use in a PyTorch model
    
    im = Image.open(image_path)
    size = 255, 255
    im.thumbnail(size)  
    box = (16, 16, 240, 240)
    im = im.crop(box)
    a = np.array(im)
    #im.show()
    image1 = (a/255 - [0.485, 0.456, 0.406])/[0.229, 0.224, 0.225]
    image = image1.transpose(2,0,1)
    return image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
#    image = image.numpy().transpose((1, 2, 0))
    image = image.transpose((1, 2, 0))    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
torch.cuda.empty_cache()

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    images = process_image(image_path)

    imshow(images)    

    #  Implement the code to predict the class from an image file
    test_loss = 0
    accuracy = 0
    
    device = 'cuda'
    model.to(device)
    
 
# convert array to tensor
    images_tensor=torch.from_numpy(images).type(torch.FloatTensor)
    images_tensor=images_tensor.to(device)
    images_tensor = images_tensor.unsqueeze(0)
    images_tensor.size()
    output = model.forward(images_tensor)
    print(output)
    ps = F.softmax(output, dim=1)
    ps.max(dim=1)
    print(ps)
#print(ps.max(dim=1))
    return ps

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
#  Display an image along with the top 5 classes

predict("image_07104.jpg", model, topk=5)
#imshow(image, ax=None, title=None)
# Out:
# tensor([[ -5.8473, -14.9843,  -7.0695, -10.9193,  -6.2424, -16.4029,
#          -16.5364,  -6.4374, -11.5430,  -5.4264,  -7.9064,  -9.2696,
#           -8.4718,  -9.6603,  -5.7565, -14.4112,  -5.7498,  -9.8394,
#           -8.8151, -12.4125,  -9.1860,  -4.6591,  -2.0311, -12.4569,
#          -13.0811,  -8.9266,  -3.1818,  -3.0789,  -4.0114,  -7.8434,
#           -3.7949, -12.2650, -13.4266, -21.6793,  -5.3687, -21.5906,
#          -17.1075, -13.9977, -12.6717,  -6.5727, -14.0869, -13.5256,
#          -10.7209, -17.5484,  -9.4419, -10.6705,  -9.3599, -11.3845,
#          -14.1247,  -7.7351, -11.1776, -12.0473, -14.2727,  -5.0718,
#           -8.9557,  -5.9393, -20.7887,  -7.8228,  -6.5678, -10.7523,
#           -8.7151,  -7.5027,  -9.5538, -10.0126,  -7.0232,  -9.3439,
#           -4.1527,  -5.4366,  -8.9517, -14.4014,  -7.4802, -14.2300,
#           -8.4729, -24.0731, -16.5144, -16.4734,  -9.3006, -15.3411,
#          -18.7953, -10.1446, -15.5455, -10.4095, -20.2220,  -4.4219,
#           -7.4332,  -7.2334,  -5.2504,  -8.3436, -18.9953, -23.8493,
#           -9.5373, -10.8348,  -5.9418,  -3.2147,  -6.2038,  -0.5148,
#          -21.5626, -16.8142, -11.1392,  -4.6373, -17.1413, -15.4339]], device='cuda:0')
# tensor([[ 2.8877e-03,  3.1074e-07,  8.5063e-04,  1.8105e-05,  1.9453e-03,
#           7.5215e-08,  6.5817e-08,  1.6006e-03,  9.7036e-06,  4.3990e-03,
#           3.6838e-04,  9.4242e-05,  2.0928e-04,  6.3763e-05,  3.1622e-03,
#           5.5118e-07,  3.1834e-03,  5.3308e-05,  1.4848e-04,  4.0673e-06,
#           1.0247e-04,  9.4751e-03,  1.3119e-01,  3.8907e-06,  2.0842e-06,
#           1.3281e-04,  4.1509e-02,  4.6011e-02,  1.8107e-02,  3.9235e-04,
#           2.2484e-02,  4.7141e-06,  1.4754e-06,  3.8441e-10,  4.6600e-03,
#           4.2005e-10,  3.7180e-08,  8.3348e-07,  3.1388e-06,  1.3980e-03,
#           7.6231e-07,  1.3364e-06,  2.2078e-05,  2.3923e-08,  7.9332e-05,
#           2.3219e-05,  8.6113e-05,  1.1370e-05,  7.3405e-07,  4.3720e-04,
#           1.3983e-05,  5.8601e-06,  6.3305e-07,  6.2712e-03,  1.2900e-04,
#           2.6339e-03,  9.3669e-10,  4.0051e-04,  1.4049e-03,  2.1397e-05,
#           1.6409e-04,  5.5157e-04,  7.0928e-05,  4.4829e-05,  8.9097e-04,
#           8.7502e-05,  1.5721e-02,  4.3544e-03,  1.2952e-04,  5.5661e-07,
#           5.6415e-04,  6.6068e-07,  2.0906e-04,  3.5090e-11,  6.7279e-08,
#           7.0093e-08,  9.1368e-05,  2.1749e-07,  6.8755e-09,  3.9288e-05,
#           1.7728e-07,  3.0144e-05,  1.6509e-09,  1.2012e-02,  5.9130e-04,
#           7.2206e-04,  5.2454e-03,  2.3791e-04,  5.6292e-09,  4.3893e-11,
#           7.2111e-05,  1.9702e-05,  2.6273e-03,  4.0166e-02,  2.0218e-03,
#           5.9761e-01,  4.3198e-10,  4.9850e-08,  1.4531e-05,  9.6840e-03,
#           3.5943e-08,  1.9822e-07]], device='cuda:0')
# tensor([[ 2.8877e-03,  3.1074e-07,  8.5063e-04,  1.8105e-05,  1.9453e-03,
#           7.5215e-08,  6.5817e-08,  1.6006e-03,  9.7036e-06,  4.3990e-03,
#           3.6838e-04,  9.4242e-05,  2.0928e-04,  6.3763e-05,  3.1622e-03,
#           5.5118e-07,  3.1834e-03,  5.3308e-05,  1.4848e-04,  4.0673e-06,
#           1.0247e-04,  9.4751e-03,  1.3119e-01,  3.8907e-06,  2.0842e-06,
#           1.3281e-04,  4.1509e-02,  4.6011e-02,  1.8107e-02,  3.9235e-04,
#           2.2484e-02,  4.7141e-06,  1.4754e-06,  3.8441e-10,  4.6600e-03,
#           4.2005e-10,  3.7180e-08,  8.3348e-07,  3.1388e-06,  1.3980e-03,
#           7.6231e-07,  1.3364e-06,  2.2078e-05,  2.3923e-08,  7.9332e-05,
#           2.3219e-05,  8.6113e-05,  1.1370e-05,  7.3405e-07,  4.3720e-04,
#           1.3983e-05,  5.8601e-06,  6.3305e-07,  6.2712e-03,  1.2900e-04,
#           2.6339e-03,  9.3669e-10,  4.0051e-04,  1.4049e-03,  2.1397e-05,
#           1.6409e-04,  5.5157e-04,  7.0928e-05,  4.4829e-05,  8.9097e-04,
#           8.7502e-05,  1.5721e-02,  4.3544e-03,  1.2952e-04,  5.5661e-07,
#           5.6415e-04,  6.6068e-07,  2.0906e-04,  3.5090e-11,  6.7279e-08,
#           7.0093e-08,  9.1368e-05,  2.1749e-07,  6.8755e-09,  3.9288e-05,
#           1.7728e-07,  3.0144e-05,  1.6509e-09,  1.2012e-02,  5.9130e-04,
#           7.2206e-04,  5.2454e-03,  2.3791e-04,  5.6292e-09,  4.3893e-11,
#           7.2111e-05,  1.9702e-05,  2.6273e-03,  4.0166e-02,  2.0218e-03,
#           5.9761e-01,  4.3198e-10,  4.9850e-08,  1.4531e-05,  9.6840e-03,
#           3.5943e-08,  1.9822e-07]], device='cuda:0')

# %%
#probs, classes = predict("image_07104.jpg", model)
#print(probs)
#print(classes)
